# %%
import pandas as pd
import numpy as np
from sklearn import linear_model

# %%
df = pd.read_csv('/kaggle/input/car-data/car data.csv')

# %%
df.sample(5)
# Out:
#      speed  car_age  experience  risk
# 101    169        1   12.345274    26
# 192    133       27    9.964954    83
# 276    130       26    6.656316    49
# 25     143       13    7.684037    77
# 19     128       15    1.508691    24

# %%
df.head()
# Out:
#    speed  car_age  experience  risk
# 0    172       22    8.104042    42
# 1     94       17   11.429461    36
# 2    186       20   14.819477    45
# 3    151       10   15.343897    38
# 4    100        6   16.455807    47

# %%
df.isnull().sum()
# Out:
# speed         0
# car_age       0
# experience    0
# risk          0
# dtype: int64

# %%
df.experience.mean()
# Out:
# 10.124916517871657

# %%
df.experience.median()
# Out:
# 10.582101444783259

# %%
from sklearn.linear_model import LinearRegression
import warnings
warnings.filterwarnings("ignore", message="X does not have valid feature names")

reg = linear_model.LinearRegression()

# %%
reg.fit(df[['speed','car_age','experience']], df.risk)
# Out:
# LinearRegression()

# %%
reg.predict([[160,10,9]])
# Out:
# array([53.8777018])

# %%
reg.coef_
# Out:
# array([-0.0302617 , -0.14473869, -0.27965041])

# %%
reg.intercept_
# Out:
# 62.68381438116153

# %%
160*-0.0302617 + 10*-0.14473869 + 9*-0.27965041 + 62.68381438116153
# Out:
# 53.877701791161535
